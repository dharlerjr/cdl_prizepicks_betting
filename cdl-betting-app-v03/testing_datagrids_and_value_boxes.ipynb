# %%
# Import setup & df_display_helpers
from setup.setup import *
from datagrid_and_value_box_helpers import *

# %%
# Load and clean cdl data
cdlDF = load_and_clean_cdl_data()
cdlDF
# Out:
# c:\Users\David Harler Jr\OneDrive\Desktop\dataClass\06-cod-analysis\03 CDL PrizePicks Betting\cdl_prizepicks_betting\cdl-betting-app-v03\setup\setup.py:39: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cdlDF = sqlio.read_sql_query("SELECT * FROM cdl_data", conn)
#       match_id match_date match_day       player                 team  \
# 0        27193 2023-12-08    Friday        aBeZy         Atlanta FaZe
# 1        27193 2023-12-08    Friday      Cellium         Atlanta FaZe
# 2        27193 2023-12-08    Friday       Drazah         Atlanta FaZe
# 3        27193 2023-12-08    Friday         Simp         Atlanta FaZe
# 4        27193 2023-12-08    Friday     Capsidal        Boston Breach
# ...        ...        ...       ...          ...                  ...
# 4827     27310 2024-05-05    Sunday       Snoopy        Boston Breach
# 4828     27310 2024-05-05    Sunday       Ghosty  Los Angeles Thieves
# 4829     27310 2024-05-05    Sunday  JoeDeceives  Los Angeles Thieves
# 4830     27310 2024-05-05    Sunday        Kremp  Los Angeles Thieves
# 4831     27310 2024-05-05    Sunday       Nastie  Los Angeles Thieves
#
#       map_num map_name   gamemode  kills  deaths  ...  series_result  map_wl  \
# 0           1  Karachi  Hardpoint     24      24  ...              1       W
# 1           1  Karachi  Hardpoint     21      19  ...              1       W
# 2           1  Karachi  Hardpoint     25      22  ...              1       W
# 3           1  Karachi  Hardpoint     33      23  ...              1       W
# 4           1  Karachi  Hardpoint     24      26  ...              0       L
# ...       ...      ...        ...    ...     ...  ...            ...     ...
# 4827        4      Rio  Hardpoint     21      29  ...              0       L
# 4828        4      Rio  Hardpoint     36      21  ...              1       W
# 4829        4      Rio  Hardpoint     26      26  ...              1       W
# 4830        4      Rio  Hardpoint     27      29  ...              1       W
# 4831        4      Rio  Hardpoint     15      24  ...              1       W
#
#       team_abbr  team_icon                  opp  opp_abbr opp_score  \
# 0           ATL       FaZe        Boston Breach       BOS       238
# 1           ATL       FaZe        Boston Breach       BOS       238
# 2           ATL       FaZe        Boston Breach       BOS       238
# 3           ATL       FaZe        Boston Breach       BOS       238
# 4           BOS     Breach         Atlanta FaZe       ATL       250
# ...         ...        ...                  ...       ...       ...
# 4827        BOS     Breach  Los Angeles Thieves       LAT       250
# 4828        LAT    Thieves        Boston Breach       BOS       193
# 4829        LAT    Thieves        Boston Breach       BOS       193
# 4830        LAT    Thieves        Boston Breach       BOS       193
# 4831        LAT    Thieves        Boston Breach       BOS       193
#
#      total_score score_diff dummy_x
# 0            488         12       0
# 1            488         12       0
# 2            488         12       0
# 3            488         12       0
# 4            488        -12       0
# ...          ...        ...     ...
# 4827         443        -57       0
# 4828         443         57       0
# 4829         443         57       0
# 4830         443         57       0
# 4831         443         57       0
#
# [4832 rows x 25 columns]

# %%
# Build series score diffs
series_score_diffs = build_series_summaries(cdlDF)
series_score_diffs
# Out:
#      match_id                 team team_abbr  map_wins  map_losses  \
# 0       27193         Atlanta FaZe       ATL         3           2
# 1       27193        Boston Breach       BOS         2           3
# 2       27194  Los Angeles Thieves       LAT         1           3
# 3       27194        Seattle Surge       SEA         3           1
# 4       27195   New York Subliners      NYSL         3           2
# ..        ...                  ...       ...       ...         ...
# 303     27308        Seattle Surge       SEA         2           3
# 304     27309      Minnesota ROKKR       MIN         0           3
# 305     27309        Toronto Ultra       TOR         3           0
# 306     27310        Boston Breach       BOS         1           3
# 307     27310  Los Angeles Thieves       LAT         3           1
#
#      series_score_diff match_date  opp
# 0                    1 2023-12-08  BOS
# 1                   -1 2023-12-08  ATL
# 2                   -2 2023-12-08  SEA
# 3                    2 2023-12-08  LAT
# 4                    1 2023-12-08   TX
# ..                 ...        ...  ...
# 303                 -1 2024-05-05  MIA
# 304                 -3 2024-05-05  TOR
# 305                  3 2024-05-05  MIN
# 306                 -2 2024-05-05  LAT
# 307                  2 2024-05-05  BOS
#
# [308 rows x 8 columns]

# %%
# Filter maps 
cdlDF = filter_maps(cdlDF)
cdlDF
# Out:
#       match_id match_date match_day       player                 team  \
# 0        27193 2023-12-08    Friday        aBeZy         Atlanta FaZe
# 1        27193 2023-12-08    Friday      Cellium         Atlanta FaZe
# 2        27193 2023-12-08    Friday       Drazah         Atlanta FaZe
# 3        27193 2023-12-08    Friday         Simp         Atlanta FaZe
# 4        27193 2023-12-08    Friday     Capsidal        Boston Breach
# ...        ...        ...       ...          ...                  ...
# 3723     27310 2024-05-05    Sunday       Snoopy        Boston Breach
# 3724     27310 2024-05-05    Sunday       Ghosty  Los Angeles Thieves
# 3725     27310 2024-05-05    Sunday  JoeDeceives  Los Angeles Thieves
# 3726     27310 2024-05-05    Sunday        Kremp  Los Angeles Thieves
# 3727     27310 2024-05-05    Sunday       Nastie  Los Angeles Thieves
#
#       map_num map_name   gamemode  kills  deaths  ...  series_result  map_wl  \
# 0           1  Karachi  Hardpoint     24      24  ...              1       W
# 1           1  Karachi  Hardpoint     21      19  ...              1       W
# 2           1  Karachi  Hardpoint     25      22  ...              1       W
# 3           1  Karachi  Hardpoint     33      23  ...              1       W
# 4           1  Karachi  Hardpoint     24      26  ...              0       L
# ...       ...      ...        ...    ...     ...  ...            ...     ...
# 3723        4      Rio  Hardpoint     21      29  ...              0       L
# 3724        4      Rio  Hardpoint     36      21  ...              1       W
# 3725        4      Rio  Hardpoint     26      26  ...              1       W
# 3726        4      Rio  Hardpoint     27      29  ...              1       W
# 3727        4      Rio  Hardpoint     15      24  ...              1       W
#
#       team_abbr  team_icon                  opp  opp_abbr opp_score  \
# 0           ATL       FaZe        Boston Breach       BOS       238
# 1           ATL       FaZe        Boston Breach       BOS       238
# 2           ATL       FaZe        Boston Breach       BOS       238
# 3           ATL       FaZe        Boston Breach       BOS       238
# 4           BOS     Breach         Atlanta FaZe       ATL       250
# ...         ...        ...                  ...       ...       ...
# 3723        BOS     Breach  Los Angeles Thieves       LAT       250
# 3724        LAT    Thieves        Boston Breach       BOS       193
# 3725        LAT    Thieves        Boston Breach       BOS       193
# 3726        LAT    Thieves        Boston Breach       BOS       193
# 3727        LAT    Thieves        Boston Breach       BOS       193
#
#      total_score score_diff dummy_x
# 0            488         12       0
# 1            488         12       0
# 2            488         12       0
# 3            488         12       0
# 4            488        -12       0
# ...          ...        ...     ...
# 3723         443        -57       0
# 3724         443         57       0
# 3725         443         57       0
# 3726         443         57       0
# 3727         443         57       0
#
# [3728 rows x 25 columns]

# %%
# Get all possible map & mode combos
map_and_mode_combos = filter_maps(cdlDF)[["gamemode", "map_name"]].drop_duplicates().sort_values(["gamemode", "map_name"]).reset_index(drop = True)
map_and_mode_combos
# Out:
#             gamemode  map_name
# 0          Hardpoint    6 Star
# 1          Hardpoint   Karachi
# 2          Hardpoint       Rio
# 3          Hardpoint  Sub Base
# 4          Hardpoint     Vista
# 5   Search & Destroy    6 Star
# 6   Search & Destroy  Highrise
# 7   Search & Destroy  Invasion
# 8   Search & Destroy   Karachi
# 9   Search & Destroy       Rio
# 10           Control  Highrise
# 11           Control  Invasion
# 12           Control   Karachi

# %%
# Test build_scoreboards
scoreboards = build_scoreboards(cdlDF, "Atlanta FaZe", "OpTic Texas", "Hardpoint")
scoreboards
# Out:
#            Date      Map Team   Player  Kills  Deaths  Margin Opponent  \
# 0    2024-05-04  Karachi  ATL    aBeZy     22      23      23      CAR
# 1    2024-05-04  Karachi  ATL  Cellium     27      18      23      CAR
# 2    2024-05-04  Karachi  ATL   Drazah     17      24      23      CAR
# 3    2024-05-04  Karachi  ATL     Simp     19      20      23      CAR
# 4    2024-05-04    Vista  ATL    aBeZy     33      25      70      CAR
# ..          ...      ...  ...      ...    ...     ...     ...      ...
# 195  2023-12-08  Karachi  ATL     Simp     33      23      12      BOS
# 196  2023-12-08  Karachi   TX    Dashy     17      21     -97     NYSL
# 197  2023-12-08  Karachi   TX    Kenny     26      22     -97     NYSL
# 198  2023-12-08  Karachi   TX     Pred     15      22     -97     NYSL
# 199  2023-12-08  Karachi   TX  Shotzzy     16      22     -97     NYSL
#
#       Player   Kills   Deaths
# 0    Clayster      23       17
# 1        FeLo      18       25
# 2       Gwinn      25       19
# 3      TJHaLy      19       24
# 4    Clayster      16       30
# ..        ...     ...      ...
# 195    Snoopy      22       30
# 196     HyDra      29       16
# 197    KiSMET      23       20
# 198       Sib      19       20
# 199      Skyz      16       18
#
# [200 rows x 11 columns]

# %%
# Test build_scoreboards
scoreboards = build_scoreboards(cdlDF, "Atlanta FaZe", "OpTic Texas", "Hardpoint", "6 Star")
scoreboards
# Out:
#           Date Team   Player  Kills  Deaths  Margin Opponent     Player   \
# 0   2024-05-04   TX    Dashy     24      21      27      LAG  Diamondcon
# 1   2024-05-04   TX    Kenny     24      22      27      LAG     Estreal
# 2   2024-05-04   TX     Pred     23      19      27      LAG        Fame
# 3   2024-05-04   TX  Shotzzy     28      22      27      LAG      Flames
# 4   2024-05-03   TX    Dashy     32      32      12      BOS   Pentagrxm
# 5   2024-05-03   TX    Kenny     30      35      12      BOS   Priestahh
# 6   2024-05-03   TX     Pred     33      32      12      BOS       Seany
# 7   2024-05-03   TX  Shotzzy     36      33      12      BOS      Snoopy
# 8   2024-04-21  ATL    aBeZy     23      17     123      TOR      CleanX
# 9   2024-04-21  ATL  Cellium     24      11     123      TOR       Envoy
# 10  2024-04-21  ATL   Drazah     28      18     123      TOR     Insight
# 11  2024-04-21  ATL     Simp     19      21     123      TOR       Scrap
# 12  2024-04-19   TX    Dashy     23      23      35      SEA          04
# 13  2024-04-19   TX    Kenny     36      21      35      SEA      Abuzah
# 14  2024-04-19   TX     Pred     21      20      35      SEA      Breszy
# 15  2024-04-19   TX  Shotzzy     32      24      35      SEA        Huke
# 16  2024-04-14  ATL    aBeZy     21      28     -43       TX       Dashy
# 17  2024-04-14  ATL  Cellium     24      21     -43       TX       Kenny
# 18  2024-04-14  ATL   Drazah     23      36     -43       TX        Pred
# 19  2024-04-14  ATL     Simp     33      23     -43       TX     Shotzzy
#
#     Kills   Deaths
# 0       16       24
# 1       24       26
# 2       17       25
# 3       27       24
# 4       32       33
# 5       33       31
# 6       25       34
# 7       42       33
# 8       22       22
# 9       14       26
# 10      13       25
# 11      18       21
# 12      23       27
# 13      26       26
# 14      18       26
# 15      21       33
# 16      33       21
# 17      27       26
# 18      25       26
# 19      23       28

# %%
# Test Compute Win Streak for all Map & Mode Combos
for index, row in map_and_mode_combos.iterrows():
    print(
        "Win Streak: " + str(
            compute_win_streak(
                cdlDF, 
                "Minnesota ROKKR",
                row["gamemode"], 
                row["map_name"]
            )
        ) + \
        "    " + row["map_name"] + " " + row["gamemode"]
    )
# Out:
# Win Streak: -1    6 Star Hardpoint
# Win Streak: 1    Karachi Hardpoint
# Win Streak: -4    Rio Hardpoint
# Win Streak: 1    Sub Base Hardpoint
# Win Streak: -3    Vista Hardpoint
# Win Streak: 2    6 Star Search & Destroy
# Win Streak: -1    Highrise Search & Destroy
# Win Streak: -2    Invasion Search & Destroy
# Win Streak: -6    Karachi Search & Destroy
# Win Streak: -1    Rio Search & Destroy
# Win Streak: -2    Highrise Control
# Win Streak: 1    Invasion Control
# Win Streak: -5    Karachi Control

# %%
# Test Compute H2H Map Record for all Map & Mode Combos
for index, row in map_and_mode_combos.iterrows():
    print(
        compute_h2h_map_record(
            cdlDF, 
            "Carolina Royal Ravens", 
            "Las Vegas Legion", 
            row["gamemode"], 
            row["map_name"]
        ) + \
        "    " + row["map_name"] + " " + row["gamemode"]
    )
# Out:
# 0 - 0    6 Star Hardpoint
# 1 - 0    Karachi Hardpoint
# 0 - 1    Rio Hardpoint
# 0 - 0    Sub Base Hardpoint
# 0 - 0    Vista Hardpoint
# 0 - 0    6 Star Search & Destroy
# 0 - 1    Highrise Search & Destroy
# 2 - 0    Invasion Search & Destroy
# 1 - 0    Karachi Search & Destroy
# 0 - 0    Rio Search & Destroy
# 0 - 0    Highrise Control
# 1 - 0    Invasion Control
# 1 - 1    Karachi Control

# %%
# Test Compute H2H Map Record for each mode overall
all_gamemodes = ["Hardpoint", "Search & Destroy", "Control"]
for gamemode in all_gamemodes:
    print(
        compute_h2h_map_record(
            cdlDF, 
            "Carolina Royal Ravens", 
            "Las Vegas Legion", 
            gamemode
        ) + \
        "    " + gamemode
    )
# Out:
# 1 - 1    Hardpoint
# 3 - 1    Search & Destroy
# 2 - 1    Control

# %%
# Test Compute H2H Series Record by Computing the H2H Series Record for each possible combination of teams

# Get teams
all_teams = sorted(cdlDF['team'].unique())

# Loop through teams
# for i in range(len(all_teams)):
#     if i != len(all_teams) - 1:
#         print(all_teams[i])
#         print("--------------------------")
#     for j in range(i + 1, len(all_teams)):
#         print(
#             f"{compute_h2h_series_record(cdlDF, all_teams[i], all_teams[j])} {all_teams[j]}"
#         )
#     if i != len(all_teams) - 1:
#         print("")

# Loop through all teams
for i in range(len(all_teams)):
    print(all_teams[i])
    print("--------------------------")
    for j in range(len(all_teams)):
        if i != j:
            print(
                f"{compute_h2h_series_record(cdlDF, all_teams[i], all_teams[j])} {all_teams[j]}"
            )
    print("")
# Out:
# Atlanta FaZe
# --------------------------
# 2 - 0 Boston Breach
# 2 - 0 Carolina Royal Ravens
# 2 - 0 Las Vegas Legion
# 2 - 1 Los Angeles Guerrillas
# 3 - 0 Los Angeles Thieves
# 1 - 0 Miami Heretics
# 2 - 0 Minnesota ROKKR
# 2 - 1 New York Subliners
# 6 - 0 OpTic Texas
# 1 - 0 Seattle Surge
# 2 - 2 Toronto Ultra
#
# Boston Breach
# --------------------------
# 0 - 2 Atlanta FaZe
# 1 - 0 Carolina Royal Ravens
# 0 - 1 Las Vegas Legion
# 0 - 2 Los Angeles Guerrillas
# 0 - 2 Los Angeles Thieves
# 1 - 1 Miami Heretics
# 1 - 2 Minnesota ROKKR
# 0 - 3 New York Subliners
# 0 - 2 OpTic Texas
# 1 - 2 Seattle Surge
# 1 - 0 Toronto Ultra
#
# Carolina Royal Ravens
# --------------------------
# 0 - 2 Atlanta FaZe
# 0 - 1 Boston Breach
# 2 - 1 Las Vegas Legion
# 2 - 0 Los Angeles Guerrillas
# 0 - 2 Los Angeles Thieves
# 1 - 2 Miami Heretics
# 0 - 1 Minnesota ROKKR
# 2 - 2 New York Subliners
# 0 - 2 OpTic Texas
# 1 - 2 Seattle Surge
# 0 - 2 Toronto Ultra
#
# Las Vegas Legion
# --------------------------
# 0 - 2 Atlanta FaZe
# 1 - 0 Boston Breach
# 1 - 2 Carolina Royal Ravens
# 2 - 1 Los Angeles Guerrillas
# 0 - 2 Los Angeles Thieves
# 2 - 1 Miami Heretics
# 1 - 0 Minnesota ROKKR
# 0 - 2 New York Subliners
# 0 - 2 OpTic Texas
# 2 - 1 Seattle Surge
# 0 - 3 Toronto Ultra
#
# Los Angeles Guerrillas
# --------------------------
# 1 - 2 Atlanta FaZe
# 2 - 0 Boston Breach
# 0 - 2 Carolina Royal Ravens
# 1 - 2 Las Vegas Legion
# 3 - 1 Los Angeles Thieves
# 0 - 1 Miami Heretics
# 2 - 2 Minnesota ROKKR
# 0 - 2 New York Subliners
# 0 - 2 OpTic Texas
# 0 - 1 Seattle Surge
# 0 - 3 Toronto Ultra
#
# Los Angeles Thieves
# --------------------------
# 0 - 3 Atlanta FaZe
# 2 - 0 Boston Breach
# 2 - 0 Carolina Royal Ravens
# 2 - 0 Las Vegas Legion
# 1 - 3 Los Angeles Guerrillas
# 2 - 0 Miami Heretics
# 1 - 1 Minnesota ROKKR
# 0 - 1 New York Subliners
# 0 - 1 OpTic Texas
# 0 - 1 Seattle Surge
# 0 - 2 Toronto Ultra
#
# Miami Heretics
# --------------------------
# 0 - 1 Atlanta FaZe
# 1 - 1 Boston Breach
# 2 - 1 Carolina Royal Ravens
# 1 - 2 Las Vegas Legion
# 1 - 0 Los Angeles Guerrillas
# 0 - 2 Los Angeles Thieves
# 2 - 0 Minnesota ROKKR
# 0 - 2 New York Subliners
# 1 - 3 OpTic Texas
# 1 - 1 Seattle Surge
# 0 - 2 Toronto Ultra
#
# Minnesota ROKKR
# --------------------------
# 0 - 2 Atlanta FaZe
# 2 - 1 Boston Breach
# 1 - 0 Carolina Royal Ravens
# 0 - 1 Las Vegas Legion
# 2 - 2 Los Angeles Guerrillas
# 1 - 1 Los Angeles Thieves
# 0 - 2 Miami Heretics
# 1 - 2 New York Subliners
# 0 - 3 OpTic Texas
# 2 - 0 Seattle Surge
# 0 - 3 Toronto Ultra
#
# New York Subliners
# --------------------------
# 1 - 2 Atlanta FaZe
# 3 - 0 Boston Breach
# 2 - 2 Carolina Royal Ravens
# 2 - 0 Las Vegas Legion
# 2 - 0 Los Angeles Guerrillas
# 1 - 0 Los Angeles Thieves
# 2 - 0 Miami Heretics
# 2 - 1 Minnesota ROKKR
# 1 - 2 OpTic Texas
# 1 - 1 Seattle Surge
# 1 - 1 Toronto Ultra
#
# OpTic Texas
# --------------------------
# 0 - 6 Atlanta FaZe
# 2 - 0 Boston Breach
# 2 - 0 Carolina Royal Ravens
# 2 - 0 Las Vegas Legion
# 2 - 0 Los Angeles Guerrillas
# 1 - 0 Los Angeles Thieves
# 3 - 1 Miami Heretics
# 3 - 0 Minnesota ROKKR
# 2 - 1 New York Subliners
# 3 - 0 Seattle Surge
# 2 - 0 Toronto Ultra
#
# Seattle Surge
# --------------------------
# 0 - 1 Atlanta FaZe
# 2 - 1 Boston Breach
# 2 - 1 Carolina Royal Ravens
# 1 - 2 Las Vegas Legion
# 1 - 0 Los Angeles Guerrillas
# 1 - 0 Los Angeles Thieves
# 1 - 1 Miami Heretics
# 0 - 2 Minnesota ROKKR
# 1 - 1 New York Subliners
# 0 - 3 OpTic Texas
# 0 - 3 Toronto Ultra
#
# Toronto Ultra
# --------------------------
# 2 - 2 Atlanta FaZe
# 0 - 1 Boston Breach
# 2 - 0 Carolina Royal Ravens
# 3 - 0 Las Vegas Legion
# 3 - 0 Los Angeles Guerrillas
# 2 - 0 Los Angeles Thieves
# 2 - 0 Miami Heretics
# 3 - 0 Minnesota ROKKR
# 1 - 1 New York Subliners
# 0 - 2 OpTic Texas
# 3 - 0 Seattle Surge

# %%
player_over_under_percentage(cdlDF, "Shotzzy", "Hardpoint", 30)
# Out:
# ('Under', '81', '4', '22', '1')

# %%
player_over_under_percentage(cdlDF, "Attach", "Search & Destroy", 7)
# Out:
# ('Over', '48', '12', '12', '1')

# %%
player_over_under_percentage(cdlDF, "Drazah", "Control", 22.5)
# Out:
# ('Over', '55', '16', '13', '0')

# %%
player_over_under_percentage(cdlDF, "Skyz", "Hardpoint", 24, "Sub Base")
# Out:
# ('Under', '62', '3', '5', '0')

# %%
player_over_under_percentage(cdlDF, "HyDra", "Search & Destroy", 12, "Rio")
# Out:
# ('Under', '100', '0', '1', '0')

# %%
player_over_under_percentage(cdlDF, "Diamondcon", "Control", 21, "Highrise")
# Out:
# ('Over', '67', '8', '4', '0')

# %%
player_over_under_percentage(cdlDF, "Gunless", "Hardpoint", 24, "Sub Base")
# Out:
# ('Under', '100', '0', '1', '0')

# %%
player_over_under_percentage(cdlDF, "Kenny", "Hardpoint", 24, "Vista")
# Out:
# ('Over', '100', '1', '0', '0')

# %%
over_under, percentage, overs, unders, hooks = player_over_under_percentage(cdlDF, "Accuracy", "Control", 21, "Invasion")
print(f"{over_under} {percentage}% \n{overs} - {unders} - {hooks}")
# Out:
# Over 55%
# 6 - 5 - 0

# %%
over_under, percentage, overs, unders, hooks = player_over_under_percentage(cdlDF, "Scrap", "Hardpoint", 23)
print(f"{over_under} {percentage}% \n{overs} - {unders} - {hooks}")
# Out:
# Over 62%
# 18 - 9 - 2

# %%
player_over_under_streak(cdlDF, "Kremp", "Hardpoint", 21.5)
# Out:
# ('Over', '2')

# %%
player_over_under_streak(cdlDF, "Vikul", "Search & Destroy", 6.5)
# Out:
# ('Under', '3')

# %%
player_over_under_streak(cdlDF, "Lucky", "Control", 21)
# Out:
# ('Over', '1')

# %%
player_over_under_streak(cdlDF, "Gio", "Hardpoint", 21, "6 Star")
# Out:
# ('Under', '1')

# %%
player_over_under_streak(cdlDF, "Pred", "Search & Destroy", 6.5, "Highrise")
# Out:
# ('Over', '1')

# %%
player_over_under_streak(cdlDF, "Gunless", "Control", 19, "Karachi")
# Out:
# ('Under', '2')

# %%
player_over_under_streak(cdlDF, "TJHaLy", "Hardpoint", 21, "Vista")
# Out:
# ('Over', '1')

# %%
player_over_under_streak(cdlDF, "Cellium", "Control", 21)
# Out:
# ('Over', '1')

# %%
player_over_under_streak(cdlDF, "Envoy", "Hardpoint", 20)
# Out:
# ('Over', '3')
