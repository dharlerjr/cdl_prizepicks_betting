# %%
# Import setup & df_display_helpers
from setup.setup import *
from datagrid_and_value_box_helpers import *

# %%
# Load and clean cdl data
cdlDF = load_and_clean_cdl_data()
cdlDF
# Out:
# c:\Users\David Harler Jr\OneDrive\Desktop\dataClass\06-cod-analysis\03 CDL PrizePicks Betting\cdl_prizepicks_betting\cdl-betting-app-v03\setup\setup.py:38: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cdlDF = sqlio.read_sql_query("SELECT * FROM cdl_data", conn)
#       match_id match_date match_day    player            team  map_num  \
# 0        27193 2023-12-08    Friday     aBeZy    Atlanta FaZe        1
# 1        27193 2023-12-08    Friday   Cellium    Atlanta FaZe        1
# 2        27193 2023-12-08    Friday    Drazah    Atlanta FaZe        1
# 3        27193 2023-12-08    Friday      Simp    Atlanta FaZe        1
# 4        27193 2023-12-08    Friday  Capsidal   Boston Breach        1
# ...        ...        ...       ...       ...             ...      ...
# 5531     70657 2024-05-18  Saturday     Vikul  Miami Heretics        4
# 5532     70657 2024-05-18  Saturday     Dashy     OpTic Texas        4
# 5533     70657 2024-05-18  Saturday     Kenny     OpTic Texas        4
# 5534     70657 2024-05-18  Saturday      Pred     OpTic Texas        4
# 5535     70657 2024-05-18  Saturday   Shotzzy     OpTic Texas        4
#
#      map_name   gamemode  kills  deaths  ...  series_result  map_wl  \
# 0     Karachi  Hardpoint     24      24  ...              1       W
# 1     Karachi  Hardpoint     21      19  ...              1       W
# 2     Karachi  Hardpoint     25      22  ...              1       W
# 3     Karachi  Hardpoint     33      23  ...              1       W
# 4     Karachi  Hardpoint     24      26  ...              0       L
# ...       ...        ...    ...     ...  ...            ...     ...
# 5531   6 Star  Hardpoint     20      27  ...              0       L
# 5532   6 Star  Hardpoint     21      22  ...              1       W
# 5533   6 Star  Hardpoint     26      26  ...              1       W
# 5534   6 Star  Hardpoint     30      27  ...              1       W
# 5535   6 Star  Hardpoint     24      29  ...              1       W
#
#       team_abbr  team_icon             opp  opp_abbr opp_score total_score  \
# 0           ATL       FaZe   Boston Breach       BOS       238         488
# 1           ATL       FaZe   Boston Breach       BOS       238         488
# 2           ATL       FaZe   Boston Breach       BOS       238         488
# 3           ATL       FaZe   Boston Breach       BOS       238         488
# 4           BOS     Breach    Atlanta FaZe       ATL       250         488
# ...         ...        ...             ...       ...       ...         ...
# 5531        MIA   Heretics     OpTic Texas        TX       250         475
# 5532         TX      OpTic  Miami Heretics       MIA       225         475
# 5533         TX      OpTic  Miami Heretics       MIA       225         475
# 5534         TX      OpTic  Miami Heretics       MIA       225         475
# 5535         TX      OpTic  Miami Heretics       MIA       225         475
#
#      score_diff dummy_x
# 0            12       0
# 1            12       0
# 2            12       0
# 3            12       0
# 4           -12       0
# ...         ...     ...
# 5531        -25       0
# 5532         25       0
# 5533         25       0
# 5534         25       0
# 5535         25       0
#
# [5536 rows x 25 columns]

# %%
# Build series score diffs
series_score_diffs = build_series_summaries(cdlDF)
series_score_diffs
# Out:
#      match_id                 team team_abbr  map_wins  map_losses  \
# 0       27193         Atlanta FaZe       ATL         3           2
# 1       27193        Boston Breach       BOS         2           3
# 2       27194  Los Angeles Thieves       LAT         1           3
# 3       27194        Seattle Surge       SEA         3           1
# 4       27195   New York Subliners      NYSL         3           2
# ..        ...                  ...       ...       ...         ...
# 347     70655        Toronto Ultra       TOR         3           1
# 348     70656   New York Subliners      NYSL         3           1
# 349     70656        Seattle Surge       SEA         1           3
# 350     70657       Miami Heretics       MIA         1           3
# 351     70657          OpTic Texas        TX         3           1
#
#      series_score_diff match_date   opp
# 0                    1 2023-12-08   BOS
# 1                   -1 2023-12-08   ATL
# 2                   -2 2023-12-08   SEA
# 3                    2 2023-12-08   LAT
# 4                    1 2023-12-08    TX
# ..                 ...        ...   ...
# 347                  2 2024-05-18    TX
# 348                  2 2024-05-18   SEA
# 349                 -2 2024-05-18  NYSL
# 350                 -2 2024-05-18    TX
# 351                  2 2024-05-18   MIA
#
# [352 rows x 8 columns]

# %%
# Filter maps 
cdlDF = filter_maps(cdlDF)
cdlDF
# Out:
#       match_id match_date match_day    player            team  map_num  \
# 0        27193 2023-12-08    Friday     aBeZy    Atlanta FaZe        1
# 1        27193 2023-12-08    Friday   Cellium    Atlanta FaZe        1
# 2        27193 2023-12-08    Friday    Drazah    Atlanta FaZe        1
# 3        27193 2023-12-08    Friday      Simp    Atlanta FaZe        1
# 4        27193 2023-12-08    Friday  Capsidal   Boston Breach        1
# ...        ...        ...       ...       ...             ...      ...
# 4427     70657 2024-05-18  Saturday     Vikul  Miami Heretics        4
# 4428     70657 2024-05-18  Saturday     Dashy     OpTic Texas        4
# 4429     70657 2024-05-18  Saturday     Kenny     OpTic Texas        4
# 4430     70657 2024-05-18  Saturday      Pred     OpTic Texas        4
# 4431     70657 2024-05-18  Saturday   Shotzzy     OpTic Texas        4
#
#      map_name   gamemode  kills  deaths  ...  series_result  map_wl  \
# 0     Karachi  Hardpoint     24      24  ...              1       W
# 1     Karachi  Hardpoint     21      19  ...              1       W
# 2     Karachi  Hardpoint     25      22  ...              1       W
# 3     Karachi  Hardpoint     33      23  ...              1       W
# 4     Karachi  Hardpoint     24      26  ...              0       L
# ...       ...        ...    ...     ...  ...            ...     ...
# 4427   6 Star  Hardpoint     20      27  ...              0       L
# 4428   6 Star  Hardpoint     21      22  ...              1       W
# 4429   6 Star  Hardpoint     26      26  ...              1       W
# 4430   6 Star  Hardpoint     30      27  ...              1       W
# 4431   6 Star  Hardpoint     24      29  ...              1       W
#
#       team_abbr  team_icon             opp  opp_abbr opp_score total_score  \
# 0           ATL       FaZe   Boston Breach       BOS       238         488
# 1           ATL       FaZe   Boston Breach       BOS       238         488
# 2           ATL       FaZe   Boston Breach       BOS       238         488
# 3           ATL       FaZe   Boston Breach       BOS       238         488
# 4           BOS     Breach    Atlanta FaZe       ATL       250         488
# ...         ...        ...             ...       ...       ...         ...
# 4427        MIA   Heretics     OpTic Texas        TX       250         475
# 4428         TX      OpTic  Miami Heretics       MIA       225         475
# 4429         TX      OpTic  Miami Heretics       MIA       225         475
# 4430         TX      OpTic  Miami Heretics       MIA       225         475
# 4431         TX      OpTic  Miami Heretics       MIA       225         475
#
#      score_diff dummy_x
# 0            12       0
# 1            12       0
# 2            12       0
# 3            12       0
# 4           -12       0
# ...         ...     ...
# 4427        -25       0
# 4428         25       0
# 4429         25       0
# 4430         25       0
# 4431         25       0
#
# [4432 rows x 25 columns]

# %%
# Get all possible map & mode combos
map_and_mode_combos = filter_maps(cdlDF)[["gamemode", "map_name"]].drop_duplicates().sort_values(["gamemode", "map_name"]).reset_index(drop = True)
map_and_mode_combos
# Out:
#             gamemode  map_name
# 0          Hardpoint    6 Star
# 1          Hardpoint   Karachi
# 2          Hardpoint       Rio
# 3          Hardpoint  Sub Base
# 4          Hardpoint     Vista
# 5   Search & Destroy    6 Star
# 6   Search & Destroy  Highrise
# 7   Search & Destroy  Invasion
# 8   Search & Destroy   Karachi
# 9   Search & Destroy       Rio
# 10           Control  Highrise
# 11           Control  Invasion
# 12           Control   Karachi

# %%
# Test build_scoreboards
scoreboards = build_scoreboards(cdlDF, "Atlanta FaZe", "OpTic Texas", "Hardpoint")
scoreboards
# Out:
#            Date       Map Team   Player  Kills  Deaths  Margin Opponent  \
# 0    2024-05-18  Sub Base   TX    Dashy     15      19      55      MIA
# 1    2024-05-18  Sub Base   TX    Kenny     23      16      55      MIA
# 2    2024-05-18  Sub Base   TX     Pred     36      17      55      MIA
# 3    2024-05-18  Sub Base   TX  Shotzzy     17      18      55      MIA
# 4    2024-05-18    6 Star   TX    Dashy     21      22      25      MIA
# ..          ...       ...  ...      ...    ...     ...     ...      ...
# 247  2023-12-08   Karachi   TX  Shotzzy     16      22     -97     NYSL
# 248  2023-12-08   Karachi  ATL    aBeZy     24      24      12      BOS
# 249  2023-12-08   Karachi  ATL  Cellium     21      19      12      BOS
# 250  2023-12-08   Karachi  ATL   Drazah     25      22      12      BOS
# 251  2023-12-08   Karachi  ATL     Simp     33      23      12      BOS
#
#        Player   Kills   Deaths
# 0        Lucky      21       20
# 1      MettalZ      15       24
# 2        ReeaL      17       25
# 3        Vikul      17       22
# 4        Lucky      22       26
# ..         ...     ...      ...
# 247       Skyz      16       18
# 248   Capsidal      24       26
# 249  Priestahh      18       24
# 250    SlasheR      24       23
# 251     Snoopy      22       30
#
# [252 rows x 11 columns]

# %%
# Test build_scoreboards
scoreboards = build_scoreboards(cdlDF, "Atlanta FaZe", "OpTic Texas", "Hardpoint", "6 Star")
scoreboards
# Out:
#           Date Team   Player  Kills  Deaths  Margin Opponent     Player   \
# 0   2024-05-18   TX    Dashy     21      22      25      MIA       Lucky
# 1   2024-05-18   TX    Kenny     26      26      25      MIA     MettalZ
# 2   2024-05-18   TX     Pred     30      27      25      MIA       ReeaL
# 3   2024-05-18   TX  Shotzzy     24      29      25      MIA       Vikul
# 4   2024-05-18   TX    Dashy     25      25     -34      TOR      CleanX
# 5   2024-05-18   TX    Kenny     17      28     -34      TOR       Envoy
# 6   2024-05-18   TX     Pred     32      31     -34      TOR     Insight
# 7   2024-05-18   TX  Shotzzy     31      29     -34      TOR       Scrap
# 8   2024-05-11  ATL    aBeZy     23      15     102      SEA          04
# 9   2024-05-11  ATL  Cellium     21      14     102      SEA      Abuzah
# 10  2024-05-11  ATL   Drazah     25      17     102      SEA      Breszy
# 11  2024-05-11  ATL     Simp     32      19     102      SEA        Huke
# 12  2024-05-04   TX    Dashy     24      21      27      LAG  Diamondcon
# 13  2024-05-04   TX    Kenny     24      22      27      LAG     Estreal
# 14  2024-05-04   TX     Pred     23      19      27      LAG        Fame
# 15  2024-05-04   TX  Shotzzy     28      22      27      LAG      Flames
# 16  2024-05-03   TX    Dashy     32      32      12      BOS   Pentagrxm
# 17  2024-05-03   TX    Kenny     30      35      12      BOS   Priestahh
# 18  2024-05-03   TX     Pred     33      32      12      BOS       Seany
# 19  2024-05-03   TX  Shotzzy     36      33      12      BOS      Snoopy
# 20  2024-04-21  ATL    aBeZy     23      17     123      TOR      CleanX
# 21  2024-04-21  ATL  Cellium     24      11     123      TOR       Envoy
# 22  2024-04-21  ATL   Drazah     28      18     123      TOR     Insight
# 23  2024-04-21  ATL     Simp     19      21     123      TOR       Scrap
# 24  2024-04-19   TX    Dashy     23      23      35      SEA          04
# 25  2024-04-19   TX    Kenny     36      21      35      SEA      Abuzah
# 26  2024-04-19   TX     Pred     21      20      35      SEA      Breszy
# 27  2024-04-19   TX  Shotzzy     32      24      35      SEA        Huke
# 28  2024-04-14  ATL    aBeZy     21      28     -43       TX       Dashy
# 29  2024-04-14  ATL  Cellium     24      21     -43       TX       Kenny
# 30  2024-04-14  ATL   Drazah     23      36     -43       TX        Pred
# 31  2024-04-14  ATL     Simp     33      23     -43       TX     Shotzzy
#
#     Kills   Deaths
# 0       22       26
# 1       23       24
# 2       39       24
# 3       20       27
# 4       27       27
# 5       26       28
# 6       28       22
# 7       32       28
# 8       16       28
# 9       19       23
# 10      13       26
# 11      17       24
# 12      16       24
# 13      24       26
# 14      17       25
# 15      27       24
# 16      32       33
# 17      33       31
# 18      25       34
# 19      42       33
# 20      22       22
# 21      14       26
# 22      13       25
# 23      18       21
# 24      23       27
# 25      26       26
# 26      18       26
# 27      21       33
# 28      33       21
# 29      27       26
# 30      25       26
# 31      23       28

# %%
# Test Compute Win Streak for all Map & Mode Combos
for index, row in map_and_mode_combos.iterrows():
    print(
        "Win Streak: " + str(
            compute_win_streak(
                cdlDF, 
                "Minnesota ROKKR",
                row["gamemode"], 
                row["map_name"]
            )
        ) + \
        "    " + row["map_name"] + " " + row["gamemode"]
    )
# Out:
# Win Streak: -3    6 Star Hardpoint
# Win Streak: -1    Karachi Hardpoint
# Win Streak: -4    Rio Hardpoint
# Win Streak: 1    Sub Base Hardpoint
# Win Streak: 1    Vista Hardpoint
# Win Streak: 2    6 Star Search & Destroy
# Win Streak: 1    Highrise Search & Destroy
# Win Streak: -2    Invasion Search & Destroy
# Win Streak: -6    Karachi Search & Destroy
# Win Streak: -2    Rio Search & Destroy
# Win Streak: -3    Highrise Control
# Win Streak: 1    Invasion Control
# Win Streak: -6    Karachi Control

# %%
# Test Compute H2H Map Record for all Map & Mode Combos
for index, row in map_and_mode_combos.iterrows():
    print(
        compute_h2h_map_record(
            cdlDF, 
            "Carolina Royal Ravens", 
            "Las Vegas Legion", 
            row["gamemode"], 
            row["map_name"]
        ) + \
        "    " + row["map_name"] + " " + row["gamemode"]
    )
# Out:
# 0 - 0    6 Star Hardpoint
# 1 - 0    Karachi Hardpoint
# 0 - 1    Rio Hardpoint
# 0 - 0    Sub Base Hardpoint
# 0 - 0    Vista Hardpoint
# 0 - 0    6 Star Search & Destroy
# 0 - 1    Highrise Search & Destroy
# 2 - 0    Invasion Search & Destroy
# 1 - 0    Karachi Search & Destroy
# 0 - 0    Rio Search & Destroy
# 0 - 0    Highrise Control
# 1 - 0    Invasion Control
# 1 - 1    Karachi Control

# %%
# Test Compute H2H Map Record for each mode overall
all_gamemodes = ["Hardpoint", "Search & Destroy", "Control"]
for gamemode in all_gamemodes:
    print(
        compute_h2h_map_record(
            cdlDF, 
            "Carolina Royal Ravens", 
            "Las Vegas Legion", 
            gamemode
        ) + \
        "    " + gamemode
    )
# Out:
# 1 - 1    Hardpoint
# 3 - 1    Search & Destroy
# 2 - 1    Control

# %%
# Test Compute H2H Series Record by Computing the H2H Series Record for each possible combination of teams

# Get teams
all_teams = sorted(cdlDF['team'].unique())

# Loop through teams
# for i in range(len(all_teams)):
#     if i != len(all_teams) - 1:
#         print(all_teams[i])
#         print("--------------------------")
#     for j in range(i + 1, len(all_teams)):
#         print(
#             f"{compute_h2h_series_record(cdlDF, all_teams[i], all_teams[j])} {all_teams[j]}"
#         )
#     if i != len(all_teams) - 1:
#         print("")

# Loop through all teams
for i in range(len(all_teams)):
    print(all_teams[i])
    print("--------------------------")
    for j in range(len(all_teams)):
        if i != j:
            print(
                f"{compute_h2h_series_record(cdlDF, all_teams[i], all_teams[j])} {all_teams[j]}"
            )
    print("")
# Out:
# Atlanta FaZe
# --------------------------
# 2 - 0 Boston Breach
# 2 - 0 Carolina Royal Ravens
# 2 - 0 Las Vegas Legion
# 2 - 1 Los Angeles Guerrillas
# 3 - 0 Los Angeles Thieves
# 2 - 0 Miami Heretics
# 2 - 0 Minnesota ROKKR
# 3 - 1 New York Subliners
# 6 - 0 OpTic Texas
# 2 - 0 Seattle Surge
# 2 - 2 Toronto Ultra
#
# Boston Breach
# --------------------------
# 0 - 2 Atlanta FaZe
# 1 - 0 Carolina Royal Ravens
# 0 - 2 Las Vegas Legion
# 0 - 2 Los Angeles Guerrillas
# 0 - 3 Los Angeles Thieves
# 1 - 1 Miami Heretics
# 1 - 2 Minnesota ROKKR
# 0 - 3 New York Subliners
# 0 - 2 OpTic Texas
# 1 - 2 Seattle Surge
# 1 - 1 Toronto Ultra
#
# Carolina Royal Ravens
# --------------------------
# 0 - 2 Atlanta FaZe
# 0 - 1 Boston Breach
# 2 - 1 Las Vegas Legion
# 3 - 0 Los Angeles Guerrillas
# 0 - 2 Los Angeles Thieves
# 1 - 2 Miami Heretics
# 1 - 1 Minnesota ROKKR
# 2 - 2 New York Subliners
# 0 - 3 OpTic Texas
# 1 - 3 Seattle Surge
# 0 - 2 Toronto Ultra
#
# Las Vegas Legion
# --------------------------
# 0 - 2 Atlanta FaZe
# 2 - 0 Boston Breach
# 1 - 2 Carolina Royal Ravens
# 2 - 1 Los Angeles Guerrillas
# 0 - 2 Los Angeles Thieves
# 2 - 2 Miami Heretics
# 1 - 0 Minnesota ROKKR
# 0 - 2 New York Subliners
# 0 - 2 OpTic Texas
# 2 - 1 Seattle Surge
# 0 - 3 Toronto Ultra
#
# Los Angeles Guerrillas
# --------------------------
# 1 - 2 Atlanta FaZe
# 2 - 0 Boston Breach
# 0 - 3 Carolina Royal Ravens
# 1 - 2 Las Vegas Legion
# 3 - 1 Los Angeles Thieves
# 0 - 2 Miami Heretics
# 2 - 2 Minnesota ROKKR
# 0 - 2 New York Subliners
# 0 - 2 OpTic Texas
# 0 - 1 Seattle Surge
# 0 - 3 Toronto Ultra
#
# Los Angeles Thieves
# --------------------------
# 0 - 3 Atlanta FaZe
# 3 - 0 Boston Breach
# 2 - 0 Carolina Royal Ravens
# 2 - 0 Las Vegas Legion
# 1 - 3 Los Angeles Guerrillas
# 2 - 1 Miami Heretics
# 1 - 1 Minnesota ROKKR
# 0 - 2 New York Subliners
# 0 - 2 OpTic Texas
# 1 - 1 Seattle Surge
# 0 - 2 Toronto Ultra
#
# Miami Heretics
# --------------------------
# 0 - 2 Atlanta FaZe
# 1 - 1 Boston Breach
# 2 - 1 Carolina Royal Ravens
# 2 - 2 Las Vegas Legion
# 2 - 0 Los Angeles Guerrillas
# 1 - 2 Los Angeles Thieves
# 2 - 0 Minnesota ROKKR
# 0 - 2 New York Subliners
# 1 - 4 OpTic Texas
# 1 - 1 Seattle Surge
# 0 - 2 Toronto Ultra
#
# Minnesota ROKKR
# --------------------------
# 0 - 2 Atlanta FaZe
# 2 - 1 Boston Breach
# 1 - 1 Carolina Royal Ravens
# 0 - 1 Las Vegas Legion
# 2 - 2 Los Angeles Guerrillas
# 1 - 1 Los Angeles Thieves
# 0 - 2 Miami Heretics
# 1 - 2 New York Subliners
# 0 - 3 OpTic Texas
# 2 - 1 Seattle Surge
# 0 - 3 Toronto Ultra
#
# New York Subliners
# --------------------------
# 1 - 3 Atlanta FaZe
# 3 - 0 Boston Breach
# 2 - 2 Carolina Royal Ravens
# 2 - 0 Las Vegas Legion
# 2 - 0 Los Angeles Guerrillas
# 2 - 0 Los Angeles Thieves
# 2 - 0 Miami Heretics
# 2 - 1 Minnesota ROKKR
# 1 - 2 OpTic Texas
# 2 - 1 Seattle Surge
# 1 - 2 Toronto Ultra
#
# OpTic Texas
# --------------------------
# 0 - 6 Atlanta FaZe
# 2 - 0 Boston Breach
# 3 - 0 Carolina Royal Ravens
# 2 - 0 Las Vegas Legion
# 2 - 0 Los Angeles Guerrillas
# 2 - 0 Los Angeles Thieves
# 4 - 1 Miami Heretics
# 3 - 0 Minnesota ROKKR
# 2 - 1 New York Subliners
# 3 - 0 Seattle Surge
# 2 - 1 Toronto Ultra
#
# Seattle Surge
# --------------------------
# 0 - 2 Atlanta FaZe
# 2 - 1 Boston Breach
# 3 - 1 Carolina Royal Ravens
# 1 - 2 Las Vegas Legion
# 1 - 0 Los Angeles Guerrillas
# 1 - 1 Los Angeles Thieves
# 1 - 1 Miami Heretics
# 1 - 2 Minnesota ROKKR
# 1 - 2 New York Subliners
# 0 - 3 OpTic Texas
# 0 - 4 Toronto Ultra
#
# Toronto Ultra
# --------------------------
# 2 - 2 Atlanta FaZe
# 1 - 1 Boston Breach
# 2 - 0 Carolina Royal Ravens
# 3 - 0 Las Vegas Legion
# 3 - 0 Los Angeles Guerrillas
# 2 - 0 Los Angeles Thieves
# 2 - 0 Miami Heretics
# 3 - 0 Minnesota ROKKR
# 2 - 1 New York Subliners
# 1 - 2 OpTic Texas
# 4 - 0 Seattle Surge

# %%
player_over_under_percentage(cdlDF, "Shotzzy", "Hardpoint", 30)
# Out:
# ('Under', '80', '6', '28', '1')

# %%
player_over_under_percentage(cdlDF, "Attach", "Search & Destroy", 7)
# Out:
# ('Under', '52', '13', '15', '1')

# %%
player_over_under_percentage(cdlDF, "Drazah", "Control", 22.5)
# Out:
# ('Over', '59', '19', '13', '0')

# %%
player_over_under_percentage(cdlDF, "Skyz", "Hardpoint", 24, "Sub Base")
# Out:
# ('Under', '62', '3', '5', '0')

# %%
player_over_under_percentage(cdlDF, "HyDra", "Search & Destroy", 12, "Rio")
# Out:
# ('Under', '100', '0', '1', '0')

# %%
player_over_under_percentage(cdlDF, "Diamondcon", "Control", 21, "Highrise")
# Out:
# ('Over', '62', '8', '5', '0')

# %%
player_over_under_percentage(cdlDF, "Gunless", "Hardpoint", 24, "Sub Base")
# Out:
# ('Under', '100', '0', '1', '0')

# %%
player_over_under_percentage(cdlDF, "Kenny", "Hardpoint", 24, "Vista")
# Out:
# ('Over', '50', '1', '1', '0')

# %%
over_under, percentage, overs, unders, hooks = player_over_under_percentage(cdlDF, "Accuracy", "Control", 21, "Invasion")
print(f"{over_under} {percentage}% \n{overs} - {unders} - {hooks}")
# Out:
# Over 55%
# 6 - 5 - 0

# %%
over_under, percentage, overs, unders, hooks = player_over_under_percentage(cdlDF, "Scrap", "Hardpoint", 23)
print(f"{over_under} {percentage}% \n{overs} - {unders} - {hooks}")
# Out:
# Over 64%
# 23 - 10 - 3

# %%
player_over_under_streak(cdlDF, "Kremp", "Hardpoint", 21.5)
# Out:
# ('Under', '1')

# %%
player_over_under_streak(cdlDF, "Vikul", "Search & Destroy", 6.5)
# Out:
# ('Under', '2')

# %%
player_over_under_streak(cdlDF, "Lucky", "Control", 21)
# Out:
# ('Under', '2')

# %%
player_over_under_streak(cdlDF, "Gio", "Hardpoint", 21, "6 Star")
# Out:
# ('Over', '1')

# %%
player_over_under_streak(cdlDF, "Pred", "Search & Destroy", 6.5, "Highrise")
# Out:
# ('Over', '1')

# %%
player_over_under_streak(cdlDF, "Gunless", "Control", 19, "Karachi")
# Out:
# ('Over', '1')

# %%
player_over_under_streak(cdlDF, "TJHaLy", "Hardpoint", 21, "Vista")
# Out:
# ('Under', '1')

# %%
player_over_under_streak(cdlDF, "Cellium", "Control", 21)
# Out:
# ('Under', '2')

# %%
player_over_under_streak(cdlDF, "Envoy", "Hardpoint", 20)
# Out:
# ('Over', '10')
