# %% [markdown]
# # Imports & setup

# %%
# Import pandas, numpy, and datetime
import pandas as pd
import pandas.io.sql as sqlio
import datetime as dt
import numpy as np

# %%
# Import psycopg2 
import psycopg2

# %%
# %cd ..
# Out:
# c:\Users\David Harler Jr\OneDrive\Desktop\dataClass\06-cod-analysis\03 CDL PrizePicks Betting\cdl_prizepicks_betting_apps\v04

# %%
# Import db password from config
from utils.setup.config import db_password

# %%
# establishing the connection
conn = psycopg2.connect(
   database = "cdl_db", 
   user = 'postgres', 
   password = db_password,
   host = '127.0.0.1', 
   port = '5433'
)

# %%
# Load data into a pandas dataframe
cdlDF = sqlio.read_sql_query("SELECT * FROM cdl_data", conn)
cdlDF
# Out:
# C:\Users\David Harler Jr\AppData\Local\Temp\ipykernel_8700\3194835332.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cdlDF = sqlio.read_sql_query("SELECT * FROM cdl_data", conn)
#       match_id  match_date match_day      player                    team  \
# 0        27242  2024-02-18    Sunday       Kremp     Los Angeles Thieves
# 1        27218  2024-01-13  Saturday   Priestahh           Boston Breach
# 2        27234  2024-01-21    Sunday        Pred             OpTic Texas
# 3        27274  2024-03-17    Sunday        Fame  Los Angeles Guerrillas
# 4        27313  2024-05-11  Saturday     oJohnny        Las Vegas Legion
# ...        ...         ...       ...         ...                     ...
# 5803     27321  2024-05-31    Friday      TJHaLy   Carolina Royal Ravens
# 5804     27321  2024-05-31    Friday  Diamondcon  Los Angeles Guerrillas
# 5805     27321  2024-05-31    Friday     Estreal  Los Angeles Guerrillas
# 5806     27321  2024-05-31    Friday        Fame  Los Angeles Guerrillas
# 5807     27321  2024-05-31    Friday      Flames  Los Angeles Guerrillas
#
#       map_num  map_name          gamemode  kills  deaths    kd  plus_minus  \
# 0           1       Rio         Hardpoint     17      29  0.59         -12
# 1           2   Karachi  Search & Destroy      6       5  1.20           1
# 2           1  Invasion         Hardpoint     17      21  0.81          -4
# 3           2  Highrise  Search & Destroy      6       6  1.00           0
# 4           3   Karachi           Control      9      19  0.47         -10
# ...       ...       ...               ...    ...     ...   ...         ...
# 5803        5    6 Star  Search & Destroy      5       8  0.63          -3
# 5804        5    6 Star  Search & Destroy      8       6  1.33           2
# 5805        5    6 Star  Search & Destroy      8       5  1.60           3
# 5806        5    6 Star  Search & Destroy     10       3  3.33           7
# 5807        5    6 Star  Search & Destroy      4       7  0.57          -3
#
#        dmg  team_score  map_result  series_result
# 0     3316         122           0              0
# 1     1222           6           1              0
# 2     2908         235           0              0
# 3     1254           6           1              1
# 4     2327           0           0              1
# ...    ...         ...         ...            ...
# 5803  1386           2           0              0
# 5804  1584           6           1              1
# 5805  1193           6           1              1
# 5806  1813           6           1              1
# 5807   714           6           1              1
#
# [5808 rows x 16 columns]

# %%
# Close the connection
conn.close()

# %%
# Drop unnecessary columns
cdlDF.drop(["match_day", "deaths", "kd", "plus_minus", "dmg", "series_result"], axis=1)
# Out:
#       match_id  match_date     player                    team  map_num  \
# 0        27242  2024-02-18      Kremp     Los Angeles Thieves        1
# 1        27218  2024-01-13  Priestahh           Boston Breach        2
# 2        27234  2024-01-21       Pred             OpTic Texas        1
# 3        27274  2024-03-17       Fame  Los Angeles Guerrillas        2
# 4        27313  2024-05-11    oJohnny        Las Vegas Legion        3
# ...        ...         ...        ...                     ...      ...
# 5683     70659  2024-05-19    Cellium            Atlanta FaZe        5
# 5684     27206  2023-12-15      Dashy             OpTic Texas        2
# 5685     27209  2023-12-16      aBeZy            Atlanta FaZe        2
# 5686     27267  2024-03-10      Lucky          Miami Heretics        4
# 5687     35635  2024-01-25      Scrap           Toronto Ultra        3
#
#       map_name          gamemode  kills  team_score  map_result
# 0          Rio         Hardpoint     17         122           0
# 1      Karachi  Search & Destroy      6           6           1
# 2     Invasion         Hardpoint     17         235           0
# 3     Highrise  Search & Destroy      6           6           1
# 4      Karachi           Control      9           0           0
# ...        ...               ...    ...         ...         ...
# 5683       Rio  Search & Destroy      7           5           0
# 5684   Karachi  Search & Destroy      5           6           1
# 5685  Highrise  Search & Destroy     10           4           0
# 5686  Sub Base         Hardpoint     17         250           1
# 5687   Karachi           Control     21           3           1
#
# [5688 rows x 10 columns]

# %%
# Correct Minnesota ROKKR team name
cdlDF.replace("Minnesota RØKKR", "Minnesota ROKKR")
# Out:
#       match_id  match_date match_day     player                    team  \
# 0        27242  2024-02-18    Sunday      Kremp     Los Angeles Thieves
# 1        27218  2024-01-13  Saturday  Priestahh           Boston Breach
# 2        27234  2024-01-21    Sunday       Pred             OpTic Texas
# 3        27274  2024-03-17    Sunday       Fame  Los Angeles Guerrillas
# 4        27313  2024-05-11  Saturday    oJohnny        Las Vegas Legion
# ...        ...         ...       ...        ...                     ...
# 5683     70659  2024-05-19    Sunday    Cellium            Atlanta FaZe
# 5684     27206  2023-12-15    Friday      Dashy             OpTic Texas
# 5685     27209  2023-12-16  Saturday      aBeZy            Atlanta FaZe
# 5686     27267  2024-03-10    Sunday      Lucky          Miami Heretics
# 5687     35635  2024-01-25  Thursday      Scrap           Toronto Ultra
#
#       map_num  map_name          gamemode  kills  deaths    kd  plus_minus  \
# 0           1       Rio         Hardpoint     17      29  0.59         -12
# 1           2   Karachi  Search & Destroy      6       5  1.20           1
# 2           1  Invasion         Hardpoint     17      21  0.81          -4
# 3           2  Highrise  Search & Destroy      6       6  1.00           0
# 4           3   Karachi           Control      9      19  0.47         -10
# ...       ...       ...               ...    ...     ...   ...         ...
# 5683        5       Rio  Search & Destroy      7       7  1.00           0
# 5684        2   Karachi  Search & Destroy      5       5  1.00           0
# 5685        2  Highrise  Search & Destroy     10       6  1.67           4
# 5686        4  Sub Base         Hardpoint     17      13  1.31           4
# 5687        3   Karachi           Control     21      15  1.40           6
#
#        dmg  team_score  map_result  series_result
# 0     3316         122           0              0
# 1     1222           6           1              0
# 2     2908         235           0              0
# 3     1254           6           1              1
# 4     2327           0           0              1
# ...    ...         ...         ...            ...
# 5683  1778           5           0              0
# 5684  1036           6           1              1
# 5685  1871           4           0              1
# 5686  3415         250           1              1
# 5687  4049           3           1              1
#
# [5688 rows x 16 columns]

# %%
# Add Map Win/Loss Column
cdlDF['map_wl'] = ["W" if x == 1 else "L" for x in cdlDF['map_result']]

# %%
# Add team colors, abbreviations, and icons

# Teams
teams = cdlDF.sort_values(by = ['team']).team.unique()

# Team Abbreviations
team_abbrs = [
    "ATL", "BOS", "CAR", "LV", "LAG", "LAT",
    "MIA", "MIN", "NYSL", "TX", "SEA", "TOR"
    ]

# Team Icons
team_icons = np.array([team.split()[-1] for team in teams])
team_icons[9] = "OpTic"

team_abbrs_icons_df = pd.DataFrame({
    "team": teams, 
    "team_abbr": team_abbrs, 
    "team_icon": team_icons
})

team_abbrs_icons_df
# Out:
#                       team team_abbr   team_icon
# 0             Atlanta FaZe       ATL        FaZe
# 1            Boston Breach       BOS      Breach
# 2    Carolina Royal Ravens       CAR      Ravens
# 3         Las Vegas Legion        LV      Legion
# 4   Los Angeles Guerrillas       LAG  Guerrillas
# 5      Los Angeles Thieves       LAT     Thieves
# 6           Miami Heretics       MIA    Heretics
# 7          Minnesota RØKKR       MIN       RØKKR
# 8       New York Subliners      NYSL   Subliners
# 9              OpTic Texas        TX       OpTic
# 10           Seattle Surge       SEA       Surge
# 11           Toronto Ultra       TOR       Ultra

# %%
# Left join cdlDF & team_abbrs_colors_df
cdlDF = pd.merge(cdlDF, team_abbrs_icons_df, on = 'team', how = 'left')
cdlDF
# Out:
#       match_id  match_date match_day     player                    team  \
# 0        27242  2024-02-18    Sunday      Kremp     Los Angeles Thieves
# 1        27218  2024-01-13  Saturday  Priestahh           Boston Breach
# 2        27234  2024-01-21    Sunday       Pred             OpTic Texas
# 3        27274  2024-03-17    Sunday       Fame  Los Angeles Guerrillas
# 4        27313  2024-05-11  Saturday    oJohnny        Las Vegas Legion
# ...        ...         ...       ...        ...                     ...
# 5683     70659  2024-05-19    Sunday    Cellium            Atlanta FaZe
# 5684     27206  2023-12-15    Friday      Dashy             OpTic Texas
# 5685     27209  2023-12-16  Saturday      aBeZy            Atlanta FaZe
# 5686     27267  2024-03-10    Sunday      Lucky          Miami Heretics
# 5687     35635  2024-01-25  Thursday      Scrap           Toronto Ultra
#
#       map_num  map_name          gamemode  kills  deaths    kd  plus_minus  \
# 0           1       Rio         Hardpoint     17      29  0.59         -12
# 1           2   Karachi  Search & Destroy      6       5  1.20           1
# 2           1  Invasion         Hardpoint     17      21  0.81          -4
# 3           2  Highrise  Search & Destroy      6       6  1.00           0
# 4           3   Karachi           Control      9      19  0.47         -10
# ...       ...       ...               ...    ...     ...   ...         ...
# 5683        5       Rio  Search & Destroy      7       7  1.00           0
# 5684        2   Karachi  Search & Destroy      5       5  1.00           0
# 5685        2  Highrise  Search & Destroy     10       6  1.67           4
# 5686        4  Sub Base         Hardpoint     17      13  1.31           4
# 5687        3   Karachi           Control     21      15  1.40           6
#
#        dmg  team_score  map_result  series_result map_wl team_abbr   team_icon
# 0     3316         122           0              0      L       LAT     Thieves
# 1     1222           6           1              0      W       BOS      Breach
# 2     2908         235           0              0      L        TX       OpTic
# 3     1254           6           1              1      W       LAG  Guerrillas
# 4     2327           0           0              1      L        LV      Legion
# ...    ...         ...         ...            ...    ...       ...         ...
# 5683  1778           5           0              0      L       ATL        FaZe
# 5684  1036           6           1              1      W        TX       OpTic
# 5685  1871           4           0              1      L       ATL        FaZe
# 5686  3415         250           1              1      W       MIA    Heretics
# 5687  4049           3           1              1      W       TOR       Ultra
#
# [5688 rows x 19 columns]

# %%
# Get Opponents, Match Scores, and Score Differentials

# Convert 'player' column to lowercase
cdlDF['player_lower'] = cdlDF['player'].str.lower()

# Sort DataFrame by specified columns
cdlDF = cdlDF.sort_values(by=['match_date', 'match_id', 'map_num', 'team', 'player_lower'])
cdlDF.reset_index(drop=True, inplace=True)

# Create DataFrame containing opponent information
opps = cdlDF.sort_values(by=['match_date', 'match_id', 'map_num', 'team', 'player_lower'], ascending=[True, True, True, False, True]) \
            [['team', 'team_abbr', 'team_score']] \
            .rename(columns={'team': 'opp', 'team_abbr': 'opp_abbr', 'team_score': 'opp_score'})
opps.reset_index(drop=True, inplace=True)

# Merge opponent DataFrame with original DataFrame
cdlDF = pd.concat([cdlDF, opps], axis=1)

# Calculate total score and score differential
cdlDF['total_score'] = cdlDF['team_score'] + cdlDF['opp_score']
cdlDF['score_diff'] = cdlDF['team_score'] - cdlDF['opp_score']

# Drop the 'player_lower' column
cdlDF = cdlDF.drop(columns=['player_lower'])

# Display the resulting DataFrame
cdlDF
# Out:
#       match_id  match_date match_day    player           team  map_num  \
# 0        27193  2023-12-08    Friday     aBeZy   Atlanta FaZe        1
# 1        27193  2023-12-08    Friday   Cellium   Atlanta FaZe        1
# 2        27193  2023-12-08    Friday    Drazah   Atlanta FaZe        1
# 3        27193  2023-12-08    Friday      Simp   Atlanta FaZe        1
# 4        27193  2023-12-08    Friday  Capsidal  Boston Breach        1
# ...        ...         ...       ...       ...            ...      ...
# 5683     70661  2024-05-19    Sunday   Shotzzy    OpTic Texas        4
# 5684     70661  2024-05-19    Sunday    CleanX  Toronto Ultra        4
# 5685     70661  2024-05-19    Sunday     Envoy  Toronto Ultra        4
# 5686     70661  2024-05-19    Sunday   Insight  Toronto Ultra        4
# 5687     70661  2024-05-19    Sunday     Scrap  Toronto Ultra        4
#
#      map_name   gamemode  kills  deaths  ...  map_result  series_result  \
# 0     Karachi  Hardpoint     24      24  ...           1              1
# 1     Karachi  Hardpoint     21      19  ...           1              1
# 2     Karachi  Hardpoint     25      22  ...           1              1
# 3     Karachi  Hardpoint     33      23  ...           1              1
# 4     Karachi  Hardpoint     24      26  ...           0              0
# ...       ...        ...    ...     ...  ...         ...            ...
# 5683      Rio  Hardpoint     37      22  ...           1              1
# 5684      Rio  Hardpoint     24      28  ...           0              0
# 5685      Rio  Hardpoint     20      31  ...           0              0
# 5686      Rio  Hardpoint     12      27  ...           0              0
# 5687      Rio  Hardpoint     30      26  ...           0              0
#
#       map_wl  team_abbr  team_icon            opp opp_abbr opp_score  \
# 0          W        ATL       FaZe  Boston Breach      BOS       238
# 1          W        ATL       FaZe  Boston Breach      BOS       238
# 2          W        ATL       FaZe  Boston Breach      BOS       238
# 3          W        ATL       FaZe  Boston Breach      BOS       238
# 4          L        BOS     Breach   Atlanta FaZe      ATL       250
# ...      ...        ...        ...            ...      ...       ...
# 5683       W         TX      OpTic  Toronto Ultra      TOR       118
# 5684       L        TOR      Ultra    OpTic Texas       TX       250
# 5685       L        TOR      Ultra    OpTic Texas       TX       250
# 5686       L        TOR      Ultra    OpTic Texas       TX       250
# 5687       L        TOR      Ultra    OpTic Texas       TX       250
#
#      total_score score_diff
# 0            488         12
# 1            488         12
# 2            488         12
# 3            488         12
# 4            488        -12
# ...          ...        ...
# 5683         368        132
# 5684         368       -132
# 5685         368       -132
# 5686         368       -132
# 5687         368       -132
#
# [5688 rows x 24 columns]

# %%
cdlDF
# Out:
#       match_id  match_date match_day     player                    team  \
# 0        27242  2024-02-18    Sunday      Kremp     Los Angeles Thieves
# 1        27218  2024-01-13  Saturday  Priestahh           Boston Breach
# 2        27234  2024-01-21    Sunday       Pred             OpTic Texas
# 3        27274  2024-03-17    Sunday       Fame  Los Angeles Guerrillas
# 4        27313  2024-05-11  Saturday    oJohnny        Las Vegas Legion
# ...        ...         ...       ...        ...                     ...
# 5683     70659  2024-05-19    Sunday    Cellium            Atlanta FaZe
# 5684     27206  2023-12-15    Friday      Dashy             OpTic Texas
# 5685     27209  2023-12-16  Saturday      aBeZy            Atlanta FaZe
# 5686     27267  2024-03-10    Sunday      Lucky          Miami Heretics
# 5687     35635  2024-01-25  Thursday      Scrap           Toronto Ultra
#
#       map_num  map_name          gamemode  kills  deaths    kd  plus_minus  \
# 0           1       Rio         Hardpoint     17      29  0.59         -12
# 1           2   Karachi  Search & Destroy      6       5  1.20           1
# 2           1  Invasion         Hardpoint     17      21  0.81          -4
# 3           2  Highrise  Search & Destroy      6       6  1.00           0
# 4           3   Karachi           Control      9      19  0.47         -10
# ...       ...       ...               ...    ...     ...   ...         ...
# 5683        5       Rio  Search & Destroy      7       7  1.00           0
# 5684        2   Karachi  Search & Destroy      5       5  1.00           0
# 5685        2  Highrise  Search & Destroy     10       6  1.67           4
# 5686        4  Sub Base         Hardpoint     17      13  1.31           4
# 5687        3   Karachi           Control     21      15  1.40           6
#
#        dmg  team_score  map_result  series_result
# 0     3316         122           0              0
# 1     1222           6           1              0
# 2     2908         235           0              0
# 3     1254           6           1              1
# 4     2327           0           0              1
# ...    ...         ...         ...            ...
# 5683  1778           5           0              0
# 5684  1036           6           1              1
# 5685  1871           4           0              1
# 5686  3415         250           1              1
# 5687  4049           3           1              1
#
# [5688 rows x 16 columns]
