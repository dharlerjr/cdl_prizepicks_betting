# %%
# Import setup
from setup.setup import load_and_clean_cdl_data, maps_to_filter
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Import setup
# ----> 2 from setup.setup import load_and_clean_cdl_data, maps_to_filter
#
# ImportError: cannot import name 'maps_to_filter' from 'setup.setup' (c:\Users\David Harler Jr\OneDrive\Desktop\dataClass\06-cod-analysis\2024.04.10 CDL PrizePicks Betting\cdl_prizepicks_betting\cdl-betting-app-v02\setup\setup.py)

# %%
# Import pandas
import pandas as pd

# %%
# Load in data
cdlDF = load_and_clean_cdl_data()
cdlDF
# Out:
# c:\Users\David Harler Jr\OneDrive\Desktop\dataClass\06-cod-analysis\2024.04.10 CDL PrizePicks Betting\cdl_prizepicks_betting\cdl-betting-app-v02\setup\setup.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   # Load data into a pandas dataframe
#       match_id  match_date match_day    player           team  map_num  \
# 0        27193  2023-12-08    Friday     aBeZy   Atlanta FaZe        1
# 1        27193  2023-12-08    Friday   Cellium   Atlanta FaZe        1
# 2        27193  2023-12-08    Friday    Drazah   Atlanta FaZe        1
# 3        27193  2023-12-08    Friday      Simp   Atlanta FaZe        1
# 4        27193  2023-12-08    Friday  Capsidal  Boston Breach        1
# ...        ...         ...       ...       ...            ...      ...
# 3755     53374  2024-03-24    Sunday      Simp   Atlanta FaZe        5
# ...

# %%
# Import helper functions from helpers.py
from ggplot_helpers import *
# Out:
# c:\Users\David Harler Jr\OneDrive\Desktop\dataClass\06-cod-analysis\2024.04.10 CDL PrizePicks Betting\cdl_prizepicks_betting\cdl-betting-app-v02\setup\setup.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
team_score_diffs("Atlanta FaZe", "Hardpoint")

# %%
team_score_diffs("Boston Breach", "Search & Destroy", "Karachi")

# %%
player_kills_overview("Clayster", "Control", 20)

# %%
player_kills_overview("Diamondcon", "Hardpoint", 20, "Karachi")

# %%
player_kills_vs_time("Ghosty", "Search & Destroy", 7)

# %%
player_kills_vs_time("Lucky", "Control", 23, "Highrise")

# %%
player_kills_vs_total("Lyynnz", "Hardpoint", 20)
# Out:
# c:\Users\David Harler Jr\anaconda3\envs\PythonData\Lib\site-packages\plotnine\stats\smoothers.py:338: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# c:\Users\David Harler Jr\anaconda3\envs\PythonData\Lib\site-packages\plotnine\stats\smoothers.py:338: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
player_kills_vs_total("HyDra", "Search & Destroy", 7, "Highrise")
# Out:
# c:\Users\David Harler Jr\anaconda3\envs\PythonData\Lib\site-packages\plotnine\stats\smoothers.py:338: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
player_kills_vs_score_diff("Huke", "Control", 20)
# Out:
# c:\Users\David Harler Jr\anaconda3\envs\PythonData\Lib\site-packages\plotnine\stats\smoothers.py:338: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
player_kills_vs_score_diff("Pred", "Hardpoint", 23, "Rio")
# Out:
# c:\Users\David Harler Jr\anaconda3\envs\PythonData\Lib\site-packages\plotnine\stats\smoothers.py:338: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
