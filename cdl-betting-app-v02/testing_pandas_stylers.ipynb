# %%
# Import setup and pandas_stylers_helpers
from setup.setup import *
from pandas_stylers_helpers import *

# %%
# Load in data
cdlDF = load_and_clean_cdl_data()
cdlDF
# Out:
# c:\Users\David Harler Jr\OneDrive\Desktop\dataClass\06-cod-analysis\2024.04.10 CDL PrizePicks Betting\cdl_prizepicks_betting\cdl-betting-app-v02\setup\setup.py:31: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cdlDF = sqlio.read_sql_query("SELECT * FROM cdl_data", conn)
#       match_id  match_date match_day    player           team  map_num  \
# 0        27193  2023-12-08    Friday     aBeZy   Atlanta FaZe        1
# 1        27193  2023-12-08    Friday   Cellium   Atlanta FaZe        1
# 2        27193  2023-12-08    Friday    Drazah   Atlanta FaZe        1
# 3        27193  2023-12-08    Friday      Simp   Atlanta FaZe        1
# 4        27193  2023-12-08    Friday  Capsidal  Boston Breach        1
# ...        ...         ...       ...       ...            ...      ...
# ...

# %%
# Build team summaries
team_summaries_DF = build_team_summaries(cdlDF)
team_summaries_DF.head(20)
# Out:
#              team          gamemode  map_name  wins  losses  win_percentage
# 0    Atlanta FaZe         Hardpoint    6 Star     0       1            0.00
# 1    Atlanta FaZe         Hardpoint   Karachi     7       2            0.78
# 2    Atlanta FaZe         Hardpoint       Rio     5       0            1.00
# 3    Atlanta FaZe         Hardpoint  Sub Base     1       5            0.17
# 4    Atlanta FaZe         Hardpoint     Vista     1       0            1.00
# 5    Atlanta FaZe  Search & Destroy  Highrise     5       3            0.62
# 6    Atlanta FaZe  Search & Destroy  Invasion     9       3            0.75
# 7    Atlanta FaZe  Search & Destroy   Karachi     3       1            0.75
# 8    Atlanta FaZe  Search & Destroy       Rio     3       0            1.00
# 9    Atlanta FaZe           Control  Highrise     6       1            0.86
# 10   Atlanta FaZe           Control  Invasion     9       3            0.75
# ...

# %%
# Check shape 
team_summaries_DF.shape
# Out:
# (170, 6)

# %%
team_summary_output = team_summaries_fn(team_summaries_DF, "OpTic Texas", "Las Vegas Legion")
team_summary_output
# Out:
# <style type="text/css">
# #T_46c2e_row0_col2, #T_46c2e_row3_col2, #T_46c2e_row4_col5, #T_46c2e_row9_col2, #T_46c2e_row14_col2 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_46c2e_row0_col5, #T_46c2e_row1_col5, #T_46c2e_row2_col2, #T_46c2e_row2_col5, #T_46c2e_row3_col5, #T_46c2e_row5_col5, #T_46c2e_row7_col5, #T_46c2e_row8_col2, #T_46c2e_row10_col5, #T_46c2e_row11_col2, #T_46c2e_row13_col2, #T_46c2e_row15_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_46c2e_row1_col2, #T_46c2e_row11_col5, #T_46c2e_row12_col5 {
#   background-color: #fcae91;
#   color: #000000;
# }
# #T_46c2e_row4_col2, #T_46c2e_row6_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: grey;
# }
# #T_46c2e_row5_col2, #T_46c2e_row9_col5, #T_46c2e_row10_col2, #T_46c2e_row13_col5, #T_46c2e_row15_col2 {
#   background-color: #bdd7e7;
#   color: #000000;
# }
# #T_46c2e_row6_col5, #T_46c2e_row7_col2, #T_46c2e_row8_col5, #T_46c2e_row12_col2, #T_46c2e_row14_col5 {
# ...

# %%
h2h_summary_output = h2h_summary_fn(cdlDF, "Atlanta FaZe", "OpTic Texas")
h2h_summary_output
# Out:
# c:\Users\David Harler Jr\OneDrive\Desktop\dataClass\06-cod-analysis\2024.04.10 CDL PrizePicks Betting\cdl_prizepicks_betting\cdl-betting-app-v02\pandas_stylers_helpers.py:84: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   h2h_summary_df_top = filter_maps(cdlDF_input) \
# <style type="text/css">
# #T_f9a69_row0_col2, #T_f9a69_row1_col5, #T_f9a69_row2_col5, #T_f9a69_row3_col2, #T_f9a69_row4_col5, #T_f9a69_row5_col5, #T_f9a69_row6_col5, #T_f9a69_row7_col5, #T_f9a69_row8_col5, #T_f9a69_row9_col5, #T_f9a69_row11_col5 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_f9a69_row0_col5, #T_f9a69_row1_col2, #T_f9a69_row2_col2, #T_f9a69_row3_col5, #T_f9a69_row4_col2, #T_f9a69_row5_col2, #T_f9a69_row6_col2, #T_f9a69_row7_col2, #T_f9a69_row8_col2, #T_f9a69_row9_col2, #T_f9a69_row11_col2 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_f9a69_row10_col2 {
#   background-color: #bdd7e7;
#   color: #000000;
# }
# #T_f9a69_row10_col5 {
# ...
