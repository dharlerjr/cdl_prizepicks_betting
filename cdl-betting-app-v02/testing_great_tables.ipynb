# %%
# Import setup
from setup.setup import *

# %%
# Import pandas
import pandas as pd

# %%
# Load in data
cdlDF = load_and_clean_cdl_data()
cdlDF
# Out:
# c:\Users\David Harler Jr\OneDrive\Desktop\dataClass\06-cod-analysis\2024.04.10 CDL PrizePicks Betting\cdl_prizepicks_betting\cdl-betting-app-v02\setup\setup.py:32: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cdlDF = sqlio.read_sql_query("SELECT * FROM cdl_data", conn)
#       match_id match_date match_day    player           team  map_num  \
# 0        27193 2023-12-08    Friday     aBeZy   Atlanta FaZe        1
# 1        27193 2023-12-08    Friday   Cellium   Atlanta FaZe        1
# 2        27193 2023-12-08    Friday    Drazah   Atlanta FaZe        1
# 3        27193 2023-12-08    Friday      Simp   Atlanta FaZe        1
# 4        27193 2023-12-08    Friday  Capsidal  Boston Breach        1
# ...        ...        ...       ...       ...            ...      ...
# ...

# %%
# Build team_summaries
team_summaries_DF = build_team_summaries(cdlDF_input = cdlDF)
team_summaries_DF
# Out:
#               team          gamemode  map_name  wins  losses  win_percentage
# 0     Atlanta FaZe         Hardpoint    6 Star     0       1            0.00
# 1     Atlanta FaZe         Hardpoint   Karachi     7       2            0.78
# 2     Atlanta FaZe         Hardpoint       Rio     5       0            1.00
# 3     Atlanta FaZe         Hardpoint  Sub Base     1       5            0.17
# 4     Atlanta FaZe         Hardpoint     Vista     1       0            1.00
# ..             ...               ...       ...   ...     ...             ...
# 187  Seattle Surge  Search & Destroy   Overall    17       8            0.68
# 188  Seattle Surge           Control   Overall     3      17            0.15
# 189  Toronto Ultra         Hardpoint   Overall    28       6            0.82
# 190  Toronto Ultra  Search & Destroy   Overall    15      11            0.58
# 191  Toronto Ultra           Control   Overall    15       8            0.65
#
# [192 rows x 6 columns]

# %%
# Filter maps
cdlDF = filter_maps(cdlDF)

# %%
from great_tables_helpers import *

# %%
team_summaries_gt_fn(team_summaries_DF, "New York Subliners", "OpTic Texas")
# Out:
# c:\Users\David Harler Jr\anaconda3\envs\PythonData\Lib\site-packages\great_tables\_tbl_data.py:235: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g_df = data.groupby(group_key)
# GT(_tbl_data=            gamemode  map_name  wins_x  losses_x  win_percentage_x  wins_y  \
# 0          Hardpoint    6 Star       0         0              0.00       1
# 1          Hardpoint   Karachi       4         3              0.57       2
# 2          Hardpoint       Rio       4         1              0.80       3
# 3          Hardpoint  Sub Base       3         4              0.43       5
# 4          Hardpoint     Vista       0         0              0.00       0
# 13         Hardpoint   Overall      20        15              0.57      28
# ...

# %%
h2h_summary_gt_fn(cdlDF, "New York Subliners", "OpTic Texas")
# Out:
# c:\Users\David Harler Jr\anaconda3\envs\PythonData\Lib\site-packages\great_tables\_tbl_data.py:235: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   g_df = data.groupby(group_key)
# GT(_tbl_data=           gamemode  map_name  wins_x  losses_x  win_percentage_x  wins_y  \
# 0         Hardpoint   Karachi       1         0              1.00       0
# 1         Hardpoint       Rio       1         0              1.00       0
# 2         Hardpoint  Sub Base       0         2              0.00       2
# 7         Hardpoint   Overall       2         2              0.50       2
# 3  Search & Destroy  Highrise       1         0              1.00       0
# 4  Search & Destroy   Karachi       1         1              0.50       1
# 8  Search & Destroy   Overall       2         1              0.67       1
# ...
